# %% [markdown]
# <a href="https://colab.research.google.com/github/Shalu012/LGMVIP-DATASCIENCE/blob/main/Image_To_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow as cvm
import matplotlib.pyplot as plt
from skimage import io

# %%
src="https://www.newshub.co.nz/home/lifestyle/2019/11/dog-years-are-a-myth-2-year-old-dogs-already-middle-aged-scientists/_jcr_content/par/video/image.dynimg.1280.q75.jpg/v1574572358818/GETTY-labrador-puppy-1120.jpg"

# %%
image=io.imread(src)

# %%
image
# Out:
# array([[[136, 171, 117],
#         [135, 170, 116],
#         [134, 169, 115],
#         ...,
#         [102, 136,  49],
#         [ 98, 132,  45],
#         [ 95, 129,  42]],
#
#        [[136, 171, 117],
#         [135, 170, 116],
#         [134, 169, 113],
#         ...,
#         [102, 136,  49],
#         [ 99, 133,  46],
#         [ 96, 130,  43]],
#
#        [[136, 171, 117],
#         [136, 171, 117],
#         [134, 169, 113],
#         ...,
#         [103, 137,  50],
#         [100, 134,  47],
#         [ 97, 131,  44]],
#
#        ...,
#
#        [[ 44,  62,  20],
#         [ 40,  58,  16],
#         [ 41,  59,  19],
#         ...,
#         [ 25,  48,   0],
#         [ 32,  55,   3],
#         [ 41,  64,  12]],
#
#        [[ 52,  70,  28],
#         [ 45,  63,  21],
#         [ 41,  59,  19],
#         ...,
#         [ 23,  43,   0],
#         [ 35,  54,   8],
#         [ 49,  68,  23]],
#
#        [[ 62,  79,  35],
#         [ 52,  69,  27],
#         [ 42,  58,  19],
# ...

# %%
cvm(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x731 at 0x7FA5D12C0C70>

# %%
image = cv2.resize(image,(500,450))
cvm(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x450 at 0x7FA5D12C0850>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[150, 147, 146, ..., 106, 108, 102],
#        [151, 147, 146, ..., 107, 108, 103],
#        [150, 147, 145, ..., 107, 109, 107],
#        ...,
#        [ 41,  48,  49, ...,  48,  47,  45],
#        [ 44,  49,  44, ...,  42,  35,  39],
#        [ 55,  42,  38, ...,  35,  24,  46]], dtype=uint8)

# %%
cvm(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FA5E57D1220>

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[105, 108, 109, ..., 149, 147, 153],
#        [104, 108, 109, ..., 148, 147, 152],
#        [105, 108, 110, ..., 148, 146, 148],
#        ...,
#        [214, 207, 206, ..., 207, 208, 210],
#        [211, 206, 211, ..., 213, 220, 216],
#        [200, 213, 217, ..., 220, 231, 209]], dtype=uint8)

# %%
cvm(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FA5E57D19A0>

# %%
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21), sigmaX=0, sigmaY=0)
image_smoothing
# Out:
# array([[108, 108, 108, ..., 148, 148, 148],
#        [108, 108, 108, ..., 148, 148, 147],
#        [108, 108, 108, ..., 147, 147, 147],
#        ...,
#        [204, 204, 203, ..., 207, 207, 207],
#        [204, 204, 203, ..., 207, 207, 208],
#        [204, 204, 203, ..., 207, 208, 208]], dtype=uint8)

# %%
cvm(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FA5E57D14F0>

# %%
def pencil_sketch(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch = pencil_sketch(gray_image, image_smoothing)
cvm(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FA5EA2B0910>

# %% [markdown]
# **Conclusion** : Thus we can convert the image into pencil sketch using Python.
